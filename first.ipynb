# %% [markdown]
# # __Austin Crime__
#
# #### Ben Takacs
# ###### Python 3.13.3
#
# ## _Exploring Data_

# %% [markdown]
# ### Obsidian Project Links
# - WIP

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import datetime

# %%
df = pd.read_csv('./data/Crime_Reports.csv')
df
# Out:
#          Incident Number     Highest Offense Description  \
# 0          2002923330284              FAMILY DISTURBANCE
# 1          2003920010029                  DEADLY CONDUCT
# 2          2003920010046          BURGLARY NON RESIDENCE
# 3          2003920010048                  DEADLY CONDUCT
# 4          2003920010049             PUBLIC INTOXICATION
# ...                  ...                             ...
# 2614905      20242241547         POSSESSION OF MARIJUANA
# 2614906      20232120660                      AUTO THEFT
# 2614907      20165028813  FAILURE TO REG AS SEX OFFENDER
# 2614908      20115031193                PROTECTIVE ORDER
# 2614909      20135056615                PROTECTIVE ORDER
#
#          Highest Offense Code Family Violence Occurred Date Time  \
# 0                        3400               N  01/29/2003  05:30
# 1                         408               N  01/01/2003  00:01
# 2                         502               N  01/01/2003  00:02
# ...

# %%
df.describe()
# Out:
#        Incident Number  Highest Offense Code  Occurred Time   Report Time  \
# count     2.614910e+06          2.614910e+06   2.614848e+06  2.614909e+06
# mean      5.936249e+10          1.710185e+03   1.313855e+03  1.325301e+03
# std       2.866050e+11          1.217282e+03   7.229112e+02  6.611990e+02
# min       2.003500e+04          1.000000e+02   0.000000e+00  0.000000e+00
# 25%       2.005310e+10          6.010000e+02   8.000000e+02  9.070000e+02
# 50%       2.010506e+10          1.400000e+03   1.423000e+03  1.406000e+03
# 75%       2.017353e+10          2.712000e+03   1.930000e+03  1.851000e+03
# max       2.025251e+12          8.905000e+03   2.400000e+03  2.359000e+03
#
#        Council District  Census Block Group
# count      2.571212e+06        2.549943e+06
# mean       4.986471e+00        4.541186e+09
# std        2.834482e+00        6.822965e+07
# min        1.000000e+00        2.195030e+08
# 25%        3.000000e+00        4.530014e+09
# ...

# %%
df.dtypes
# Out:
# Incident Number                  int64
# Highest Offense Description     object
# Highest Offense Code             int64
# Family Violence                 object
# Occurred Date Time              object
# Occurred Date                   object
# Occurred Time                  float64
# Report Date Time                object
# Report Date                     object
# Report Time                    float64
# Location Type                   object
# Council District               float64
# APD Sector                      object
# APD District                    object
# Clearance Status                object
# Clearance Date                  object
# UCR Category                    object
# Category Description            object
# Census Block Group             float64
# dtype: object

# %%
df['Occurred Date'] = pd.to_datetime(df['Occurred Date'])

df['Occurred Date']
# Out:
# 0         2003-01-29
# 1         2003-01-01
# 2         2003-01-01
# 3         2003-01-01
# 4         2003-01-01
#              ...
# 2614905   2024-08-11
# 2614906   2023-07-29
# 2614907   2016-07-13
# 2614908   2011-06-23
# 2614909   2013-12-10
# Name: Occurred Date, Length: 2614910, dtype: datetime64[ns]

# %%
df['Occurred Date'].describe()
# Out:
# count                          2614910
# mean     2013-03-02 13:22:33.021557504
# min                2003-01-01 00:00:00
# 25%                2007-12-13 00:00:00
# 50%                2012-07-29 00:00:00
# 75%                2018-04-11 00:00:00
# max                2025-04-05 00:00:00
# Name: Occurred Date, dtype: object
